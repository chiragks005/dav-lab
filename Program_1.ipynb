# %% [markdown]
# <a href="https://colab.research.google.com/github/chiragks005/dav-lab/blob/main/Program_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
arr = np.array([10,20,30,40,50])
print("\n1. Numpy Array")
print("Array:", arr)
# Out:
# 1. Numpy Array
# Array: [10 20 30 40 50]

# %%
print("First element:", arr[0])
print("Third element:", arr[2])
print("Last element:", arr[-1])
# Out:
# First element: 10
# Third element: 30
# Last element: 50

# %%
print("\n--- Array Slicing ---")
print("First three elements:", arr[0:3])
print("Element from index 2:", arr[2:])
print("Last three elements:", arr[-3:])
# Out:
# --- Array Slicing ---
# First three elements: [10 20 30]
# Element from index 2: [30 40 50]
# Last three elements: [30 40 50]

# %%
print("\n--- Basic Array Operations ---")
print("Add 5:", arr + 5)
print("Subtract 5:", arr - 5)
print("Multiply by 5:", arr * 2)
print("Divide by 5:", arr / 10)
# Out:
# --- Basic Array Operations ---
# Add 5: [15 25 35 45 55]
# Subtract 5: [ 5 15 25 35 45]
# Multiply by 5: [ 20  40  60  80 100]
# Divide by 5: [1. 2. 3. 4. 5.]

# %%
print("\n --- Mathematical Operations ---")
print("Sum:", np.sum(arr))
print("Mean:", np.mean(arr))
print("Maximum:", np.max(arr))
print("Minimum:", np.min(arr))
# Out:
#  --- Mathematical Operations ---
# Sum: 150
# Mean: 30.0
# Maximum: 50
# Minimum: 10

# %%
arr = np.array([10,20,30,40,50,60])
new_arr = arr.reshape(6,1)
print("Original Array:")
print(arr)
print("\n Reshaped Array:")
print(new_arr)
# Out:
# Original Array:
# [10 20 30 40 50 60]
#
#  Reshaped Array:
# [[10]
#  [20]
#  [30]
#  [40]
#  [50]
#  [60]]

# %%
data = {
    "Name" : ["Asha" , "Ravi" , "Meera" , "Karan"],
    "Marks": [88,72,91,65],
    "Branch" : ["CSE", "ECE", "CSE", "ISE"]
}
df = pd.DataFrame(data)
print("\n--- Panda DataFrame---")
print(df)
# Out:
# --- Panda DataFrame---
#     Name  Marks Branch
# 0   Asha     88    CSE
# 1   Ravi     72    ECE
# 2  Meera     91    CSE
# 3  Karan     65    ISE

# %%
print("Name Column:")
print(df["Name"])
# Out:
# Name Column:
# 0     Asha
# 1     Ravi
# 2    Meera
# 3    Karan
# Name: Name, dtype: object

# %%
print("Name and Marks Columns:")
print(df[["Name" , "Marks"]])
# Out:
# Name and Marks Columns:
#     Name  Marks
# 0   Asha     88
# 1   Ravi     72
# 2  Meera     91
# 3  Karan     65

# %%
print("Average Marks:", df["Marks"].mean())
print("Highest Marks:", df["Marks"].max())
print("Lowest Marks:", df["Marks"].min())
# Out:
# Average Marks: 79.0
# Highest Marks: 91
# Lowest Marks: 65

# %%
print("--- Original DataFrame---")
print(df)
print("--- Row Indexing---")
print("First Row:")
print(df.iloc[0])
print("\n Second Row:")
print("df.line[1]")
print("\n Third Row:")
print(df.iloc[2])
print("\n Fourth Row:")
print(df.iloc[3])
# Out:
# --- Original DataFrame---
#     Name  Marks Branch
# 0   Asha     88    CSE
# 1   Ravi     72    ECE
# 2  Meera     91    CSE
# 3  Karan     65    ISE
# --- Row Indexing---
# First Row:
# Name      Asha
# Marks       88
# Branch     CSE
# Name: 0, dtype: object
#
#  Second Row:
# df.line[1]
#
#  Third Row:
# Name      Meera
# Marks        91
# Branch      CSE
# Name: 2, dtype: object
#
#  Fourth Row:
# Name      Karan
# Marks        65
# Branch      ISE
# Name: 3, dtype: object

# %%
print("--- Specific values ---")
print("Marks od first student:", df.iloc[0,1])
print("Marks of Ravi:",df.iloc[1,1])
print("Branch of Meera:", df.iloc[2,2])
print("Name of Karan:", df.iloc[3,0])
# Out:
# --- Specific values ---
# Marks od first student: 88
# Marks of Ravi: 72
# Branch of Meera: CSE
# Name of Karan: Karan

# %%
print("\n--- Data Filtering ---")
result =df[df["Marks"]>85]
print("Students with Marks greater than 85:")
print(result)
# Out:
# --- Data Filtering ---
# Students with Marks greater than 85:
#     Name  Marks Branch
# 0   Asha     88    CSE
# 2  Meera     91    CSE

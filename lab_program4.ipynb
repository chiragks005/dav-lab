# %% [markdown]
# <a href="https://colab.research.google.com/github/chiragks005/dav-lab/blob/main/lab_program4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.DataFrame({
    "Marks" : [80,70,None,90,60],
    "Attendance": [90, None, 85, 80, 75],
    "Department" :["CSE","ECE","CSE",None,"ECE"]
})

# %%
df["Marks"] = df["Marks"].fillna(df["Marks"].mean())
df["Attendance"] = df["Attendance"].fillna(df["Attendance"].median())
df["Attendance"] = df["Attendance"].ffill()
df["Department"] = df["Department"].fillna(df["Department"].mode()[0])
le = LabelEncoder()
df["Department"] = le.fit_transform(df["Department"])
print(df)
# Out:
#    Marks  Attendance  Department
# 0   80.0        90.0           0
# 1   70.0        82.5           1
# 2   75.0        85.0           0
# 3   90.0        80.0           0
# 4   60.0        75.0           1

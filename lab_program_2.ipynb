# %% [markdown]
# <a href="https://colab.research.google.com/github/chiragks005/dav-lab/blob/main/lab_program_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = {
    "Student_ID": [101,102,103,104,105,106,102,107],
    "Student": ["Asha","Ravi","Priya","John",
                "Anu","Kiran","Ravi","Meena"],
    "Department" : ["CSE","CSE","ECE","ECE",
                    "CSE","EEE","CSE","EEE"],
    "Attendance" : [98,75,95,60,80,70,75,85],
    "Internal_Marks" : [85,70,90,55,78,65,70,None],
    "Final_Marks" : [88,72,92,50,80,68,72,82]
}

# %%
df = pd.DataFrame(data)
df.to_csv("students.csv",index=False)
print("students.csv created successfully")
# Out:
# students.csv created successfully

# %%
df = pd.read_csv("students.csv")
print("Original Dataset:")
print(df)
# Out:
# Original Dataset:
#    Student_ID Student Department  Attendance  Internal_Marks  Final_Marks
# 0         101    Asha        CSE          98            85.0           88
# 1         102    Ravi        CSE          75            70.0           72
# 2         103   Priya        ECE          95            90.0           92
# 3         104    John        ECE          60            55.0           50
# 4         105     Anu        CSE          80            78.0           80
# 5         106   Kiran        EEE          70            65.0           68
# 6         102    Ravi        CSE          75            70.0           72
# 7         107   Meena        EEE          85             NaN           82

# %%
print("\nFirst Five Records:")
print(df.head())
# Out:
# First Five Records:
#    Student_ID Student Department  Attendance  Internal_Marks  Final_Marks
# 0         101    Asha        CSE          98            85.0           88
# 1         102    Ravi        CSE          75            70.0           72
# 2         103   Priya        ECE          95            90.0           92
# 3         104    John        ECE          60            55.0           50
# 4         105     Anu        CSE          80            78.0           80

# %%
print("\nDataset Shape")
print(df.shape)
# Out:
# Dataset Shape
# (8, 6)

# %%
print("\ncheck datatypes:")
print(df.dtypes)
# Out:
# check datatypes:
# Student_ID          int64
# Student            object
# Department         object
# Attendance          int64
# Internal_Marks    float64
# Final_Marks         int64
# dtype: object

# %%
print("\n Last Five Records")
print(df.tail)
# Out:
#  Last Five Records
# <bound method NDFrame.tail of    Student_ID Student Department  Attendance  Internal_Marks  Final_Marks
# 0         101    Asha        CSE          98            85.0           88
# 1         102    Ravi        CSE          75            70.0           72
# 2         103   Priya        ECE          95            90.0           92
# 3         104    John        ECE          60            55.0           50
# 4         105     Anu        CSE          80            78.0           80
# 5         106   Kiran        EEE          70            65.0           68
# 6         102    Ravi        CSE          75            70.0           72
# 7         107   Meena        EEE          85             NaN           82>

# %%
print("\nDescriptive Statistics:")
df.describe()
# Out:
# Descriptive Statistics:
#        Student_ID  Attendance  Internal_Marks  Final_Marks
# count     8.00000    8.000000        7.000000     8.000000
# mean    103.75000   79.750000       73.285714    75.500000
# std       2.12132   12.668859       11.996031    13.212548
# min     101.00000   60.000000       55.000000    50.000000
# 25%     102.00000   73.750000       67.500000    71.000000
# 50%     103.50000   77.500000       70.000000    76.000000
# 75%     105.25000   87.500000       81.500000    83.500000
# max     107.00000   98.000000       90.000000    92.000000

# %%
print("\n Missing Values:")
print(df.isnull().sum())
# Out:
#  Missing Values:
# Student_ID        0
# Student           0
# Department        0
# Attendance        0
# Internal_Marks    1
# Final_Marks       0
# dtype: int64

# %%
print("\nNumber of Duplicate Records:")
print(df.duplicated().sum())
df = df.drop_duplicates()
# Out:
# Number of Duplicate Records:
# 0

# %%
print("\nAverage final Marks by Department:")
print(
 (df.groupby("Department")["Final_Marks"].mean())
)
# Out:
# Average final Marks by Department:
# Department
# CSE    80.0
# ECE    71.0
# EEE    75.0
# Name: Final_Marks, dtype: float64

# %%
courses = pd.DataFrame({
    "Student_ID" :[101,102,103,104,105,106,107],
    "Course":[
        "Python",
        "Python",
        "Java",
        "Python",
        "Java",
        "Python",
        "Java"
    ]
})

# %%
merged_df = pd.merge(df,courses,on="Student_ID")

print("\nMerged Dataset:")
print(merged_df)
# Out:
# Merged Dataset:
#    Student_ID Student Department  Attendance  Internal_Marks  Final_Marks  \
# 0         101    Asha        CSE          98            85.0           88
# 1         102    Ravi        CSE          75            70.0           72
# 2         103   Priya        ECE          95            90.0           92
# 3         104    John        ECE          60            55.0           50
# 4         105     Anu        CSE          80            78.0           80
# 5         106   Kiran        EEE          70            65.0           68
# 6         107   Meena        EEE          85             NaN           82
#
#    Course
# 0  Python
# 1  Python
# 2    Java
# 3  Python
# 4    Java
# 5  Python
# 6    Java
